# %%
import kagglehub
import os
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.feature_extraction.text import CountVectorizer
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = kagglehub.dataset_download("sahideseker/spam-mail-classifier-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\grace\.cache\kagglehub\datasets\sahideseker\spam-mail-classifier-dataset\versions\1

# %%
os.chdir(path)
os.listdir()

df=pd.read_csv("spam_mail_classifier.csv")

# %%
df.head()
X=df["email_text"]
y=df["label"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=125)

# %%
vectorizer = CountVectorizer()
X_train_vectorized = vectorizer.fit_transform(X_train)
X_test_vectorized = vectorizer.transform(X_test)

# %%
model = MultinomialNB()
model.fit(X_train_vectorized, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(X_test_vectorized)
print(y_pred)
print(y_test)
# Out:
# ['ham' 'spam' 'ham' 'ham' 'ham' 'ham' 'ham' 'spam' 'ham' 'ham' 'spam'
#  'ham' 'ham' 'spam' 'ham' 'spam' 'ham' 'spam' 'spam' 'ham' 'spam' 'ham'
#  'ham' 'spam' 'ham' 'ham' 'ham' 'spam' 'ham' 'spam' 'ham' 'ham' 'spam'
#  'ham' 'ham' 'ham' 'ham' 'ham' 'spam' 'ham' 'ham' 'ham' 'spam' 'ham'
#  'spam' 'spam' 'ham' 'spam' 'spam' 'ham' 'ham' 'spam' 'spam' 'ham' 'ham'
#  'spam' 'ham' 'spam' 'ham' 'spam' 'ham' 'ham' 'spam' 'spam' 'spam' 'ham'
#  'ham' 'ham' 'spam' 'ham' 'ham' 'ham' 'spam' 'spam' 'ham' 'ham' 'ham'
#  'ham' 'spam' 'spam' 'ham' 'spam' 'ham' 'spam' 'ham' 'ham' 'ham' 'ham'
#  'ham' 'spam' 'ham' 'spam' 'ham' 'ham' 'spam' 'ham' 'ham' 'ham' 'ham'
#  'spam' 'spam' 'spam' 'spam' 'spam' 'ham' 'ham' 'spam' 'ham' 'ham' 'spam'
#  'spam' 'ham' 'ham' 'ham' 'spam' 'ham' 'ham' 'ham' 'spam' 'ham' 'spam'
#  'ham' 'spam' 'spam' 'ham' 'spam' 'ham' 'spam' 'ham' 'ham' 'spam' 'ham'
#  'spam' 'ham' 'ham' 'ham' 'ham' 'spam' 'ham' 'ham' 'ham' 'spam' 'spam'
#  'ham' 'ham' 'spam' 'ham' 'ham' 'spam' 'ham' 'ham' 'ham' 'ham' 'spam'
#  'spam' 'ham' 'ham' 'ham' 'ham' 'spam' 'ham' 'spam' 'spam' 'ham' 'spam'
#  'ham' 'ham' 'ham' 'ham' 'spam' 'ham' 'spam' 'spam' 'ham' 'ham' 'spam'
#  'spam' 'ham' 'spam' 'spam' 'spam' 'spam' 'spam' 'ham' 'spam' 'ham' 'ham'
#  'ham' 'ham' 'spam' 'spam' 'spam' 'spam' 'ham' 'spam' 'ham' 'ham' 'spam'
#  'ham' 'ham' 'spam' 'ham' 'ham' 'spam' 'ham' 'ham' 'ham' 'spam' 'ham'
#  'spam' 'spam' 'spam' 'spam' 'ham' 'ham' 'ham' 'spam' 'spam' 'ham' 'spam'
#  'spam' 'ham' 'ham' 'spam' 'ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'spam'
#  'spam' 'spam' 'spam' 'spam' 'ham' 'spam' 'ham' 'spam' 'ham' 'spam' 'spam'
#  'ham' 'spam' 'ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'spam' 'ham' 'spam'
#  'ham' 'ham' 'ham' 'ham' 'ham' 'spam' 'ham' 'ham' 'ham' 'ham' 'ham' 'spam'
#  'ham' 'ham' 'spam' 'spam' 'spam' 'ham' 'ham' 'ham' 'ham' 'spam' 'spam'
#  'ham' 'spam' 'spam' 'ham' 'spam' 'ham' 'spam' 'ham' 'ham' 'spam' 'spam'
#  'spam' 'ham' 'spam' 'spam' 'ham' 'spam' 'spam' 'spam' 'ham' 'ham' 'spam'
#  'ham' 'ham' 'spam' 'spam' 'spam' 'ham' 'spam' 'ham' 'ham' 'ham' 'ham'
#  'spam' 'ham' 'spam' 'ham' 'spam' 'ham' 'ham' 'ham' 'ham' 'ham' 'ham'
#  'ham' 'spam' 'spam' 'ham' 'spam' 'ham' 'spam' 'ham' 'spam' 'ham' 'ham'
#  'ham' 'ham' 'spam' 'spam' 'spam' 'ham' 'spam' 'spam' 'spam' 'spam' 'ham'
#  'ham' 'ham' 'ham' 'ham' 'ham' 'spam' 'ham' 'ham' 'spam' 'ham' 'ham' 'ham'
#  'ham' 'spam' 'spam' 'ham' 'ham' 'ham' 'ham' 'spam' 'ham' 'ham' 'spam'
#  'ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'spam' 'spam' 'spam' 'spam'
#  'spam' 'spam' 'ham' 'ham' 'spam' 'spam' 'ham' 'ham' 'spam' 'spam' 'ham'
#  'spam' 'ham' 'ham' 'spam' 'ham' 'spam' 'ham' 'spam' 'ham' 'ham' 'spam'
#  'ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'spam' 'spam'
#  'spam' 'spam' 'spam' 'spam' 'spam' 'spam' 'spam' 'spam' 'spam' 'ham'
#  'ham' 'spam' 'ham' 'ham' 'spam' 'ham' 'ham' 'spam' 'spam' 'ham' 'ham'
#  'spam' 'spam' 'spam' 'ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'spam'
#  'spam' 'ham' 'ham' 'spam' 'ham' 'ham' 'spam' 'ham' 'spam' 'spam' 'spam'
#  'spam' 'spam' 'ham' 'ham' 'ham' 'ham' 'ham' 'spam' 'ham' 'ham' 'spam'
#  'ham' 'spam' 'spam' 'ham' 'ham' 'ham' 'ham' 'spam' 'ham' 'spam' 'spam'
#  'spam' 'spam' 'spam' 'ham' 'ham' 'spam' 'ham' 'ham' 'spam' 'spam' 'spam'
#  'ham' 'ham' 'ham' 'spam' 'spam' 'ham' 'ham' 'ham' 'ham' 'spam' 'ham'
#  'spam' 'ham' 'ham' 'ham' 'ham' 'spam' 'ham' 'ham' 'spam' 'ham' 'ham'
#  'spam' 'ham' 'ham' 'spam' 'spam' 'spam' 'ham' 'spam' 'spam' 'ham' 'ham'
#  'ham' 'ham' 'spam' 'ham' 'spam' 'spam' 'ham' 'spam' 'spam' 'spam' 'ham'
#  'spam' 'spam' 'ham' 'ham' 'spam' 'ham' 'spam' 'spam' 'spam' 'ham' 'ham'
#  'ham' 'spam' 'ham' 'ham' 'ham' 'ham' 'ham' 'spam' 'ham' 'ham' 'ham' 'ham'
#  'spam' 'ham' 'spam' 'spam' 'spam' 'ham' 'ham' 'spam' 'spam' 'ham' 'ham'
#  'ham' 'ham' 'spam' 'spam' 'spam' 'spam' 'spam' 'ham' 'ham' 'spam' 'ham'
#  'spam' 'ham' 'ham' 'spam' 'ham' 'ham' 'spam' 'ham' 'ham' 'spam' 'ham'
#  'ham' 'ham' 'ham' 'spam' 'spam' 'ham' 'ham' 'spam' 'spam' 'ham' 'ham'
#  'ham' 'spam' 'spam' 'spam' 'spam' 'spam' 'ham' 'ham' 'ham' 'spam' 'ham'
#  'ham' 'ham' 'ham' 'spam' 'spam' 'ham' 'ham' 'ham' 'spam' 'ham' 'spam'
#  'spam' 'spam' 'ham' 'spam' 'spam' 'ham' 'spam' 'spam' 'ham' 'ham' 'ham'
#  'ham' 'ham' 'ham' 'spam' 'spam' 'spam' 'spam' 'ham' 'ham' 'ham' 'spam'
#  'ham' 'ham' 'spam' 'spam' 'ham' 'spam' 'ham' 'spam' 'spam' 'ham' 'ham'
#  'spam' 'ham' 'ham' 'ham' 'ham' 'spam' 'spam' 'ham' 'spam' 'ham' 'ham'
#  'spam' 'ham' 'ham' 'spam' 'ham' 'spam' 'ham' 'ham' 'ham' 'spam' 'ham'
#  'ham' 'ham' 'spam' 'ham' 'ham' 'spam' 'spam' 'ham' 'ham' 'ham' 'spam'
#  'ham' 'spam' 'ham' 'ham' 'ham' 'ham' 'ham' 'spam' 'ham' 'spam' 'spam'
#  'ham' 'ham' 'ham' 'spam' 'ham' 'ham' 'ham' 'ham' 'spam' 'ham' 'spam'
#  'ham' 'ham' 'spam' 'spam' 'ham' 'ham' 'ham' 'spam' 'spam' 'spam' 'ham'
#  'spam' 'spam' 'ham' 'ham' 'ham' 'ham' 'spam' 'ham' 'spam' 'ham' 'ham'
#  'spam' 'ham' 'ham' 'spam' 'ham' 'spam' 'spam' 'ham' 'ham' 'spam' 'spam'
#  'ham' 'spam' 'ham' 'spam' 'spam' 'ham' 'ham' 'ham' 'spam' 'spam' 'spam'
#  'ham' 'ham' 'ham' 'spam' 'ham' 'spam' 'spam' 'ham' 'spam' 'spam' 'ham'
#  'ham' 'spam' 'spam' 'ham' 'ham' 'ham' 'spam' 'ham' 'ham' 'ham' 'spam'
#  'ham' 'ham' 'ham' 'spam' 'spam' 'spam' 'spam' 'ham' 'spam' 'spam' 'ham'
#  'ham' 'spam' 'ham' 'spam' 'ham' 'ham' 'spam' 'spam' 'ham' 'ham' 'ham'
#  'spam' 'ham' 'ham' 'ham' 'ham' 'spam' 'ham' 'spam' 'ham' 'spam' 'spam'
#  'ham' 'spam' 'ham' 'ham' 'ham' 'spam' 'spam' 'ham' 'spam' 'spam' 'ham'
#  'ham' 'spam' 'ham' 'spam' 'spam' 'spam' 'spam' 'spam' 'ham' 'spam' 'ham'
#  'ham' 'ham' 'ham' 'spam' 'spam' 'ham' 'spam' 'ham' 'ham' 'ham' 'ham'
#  'ham' 'spam' 'ham' 'ham' 'ham' 'spam' 'spam' 'ham' 'ham' 'ham' 'spam'
#  'spam' 'spam' 'ham' 'ham' 'ham' 'spam' 'ham' 'ham' 'spam' 'ham' 'spam'
#  'ham' 'ham' 'spam' 'ham' 'ham' 'ham' 'ham' 'spam' 'ham' 'ham' 'ham'
#  'spam' 'ham' 'ham' 'spam' 'ham' 'ham' 'ham' 'ham' 'spam' 'ham' 'ham'
#  'ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'spam' 'ham' 'spam' 'spam' 'spam'
#  'ham' 'spam' 'spam' 'spam' 'ham' 'spam']
# 441     ham
# 114    spam
# 699     ham
# 406     ham
# 585     ham
#        ...
# 303    spam
# 705    spam
# 170    spam
# 47      ham
# 35     spam
# Name: label, Length: 900, dtype: object

# %%
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

print(f'Accuracy: {accuracy *100}%')

class_labels = np.unique(y_test)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix Heatmap')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy: 100.0%
